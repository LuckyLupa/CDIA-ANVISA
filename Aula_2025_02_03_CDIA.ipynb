# %% [markdown]
# <a href="https://colab.research.google.com/github/LuckyLupa/CDIA-ANVISA/blob/main/Aula_2025_02_03_CDIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
base = pd.read_csv('https://raw.githubusercontent.com/andfranca/proadi-sus-ciencia-de-dados-ia/main/notebooks/imersao%20-%20regressao/custo_medico_processamento.csv')

# %%
base.head()
# Out:
#    idade       sexo     IMC  filhos fumante    regiao custos_medicos  \
# 0     19   feminino    27,9     NaN     sim  sudoeste      16884,924
# 1     18  masculino   33,77     1.0     NaN   sudeste      1725,5523
# 2     28  masculino      33     3.0     NaN   sudeste       4449,462
# 3     33  masculino  22,705     NaN     NaN  noroeste    21984,47061
# 4     32  masculino   28,88     NaN     NaN  noroeste      3866,8552
#
#    doencas_cronicas  consultas_ano  atividade_fisica      dieta_saudavel  \
# 0               NaN              4                 6  0,3901543721009203
# 1               2.0              7                 3        0,3329179435
# 2               NaN              2                 4         0,155487985
# 3               NaN              2                 2  0,5245121597655716
# 4               NaN              3                 3  0,5904194576901376
#
#    uso_medicamentos
# 0                 2
# 1                 0
# 2                 0
# 3                 4
# ...

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2772 entries, 0 to 2771
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   idade             2772 non-null   int64
#  1   sexo              2772 non-null   object
#  2   IMC               2772 non-null   object
#  3   filhos            1586 non-null   float64
#  4   fumante           564 non-null    object
#  5   regiao            2772 non-null   object
#  6   custos_medicos    2772 non-null   object
#  7   doencas_cronicas  1513 non-null   float64
#  8   consultas_ano     2772 non-null   int64
#  9   atividade_fisica  2772 non-null   int64
#  10  dieta_saudavel    2772 non-null   object
#  11  uso_medicamentos  2772 non-null   int64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 260.0+ KB

# %%
base.isnull().sum()
# Out:
# idade                  0
# sexo                   0
# IMC                    0
# filhos              1186
# fumante             2208
# regiao                 0
# custos_medicos         0
# doencas_cronicas    1259
# consultas_ano          0
# atividade_fisica       0
# dieta_saudavel         0
# uso_medicamentos       0
# dtype: int64

# %%
base.dropna(axis=1)
# Out:
#       idade       sexo     IMC    regiao custos_medicos  consultas_ano  \
# 0        19   feminino    27,9  sudoeste      16884,924              4
# 1        18  masculino   33,77   sudeste      1725,5523              7
# 2        28  masculino      33   sudeste       4449,462              2
# 3        33  masculino  22,705  noroeste    21984,47061              2
# 4        32  masculino   28,88  noroeste      3866,8552              3
# ...     ...        ...     ...       ...            ...            ...
# 2767     47   feminino   45,32   sudeste      8569,8618              4
# 2768     21   feminino    34,6  sudoeste       2020,177              6
# 2769     19  masculino   26,03  noroeste     16450,8947              6
# 2770     23  masculino  18,715  noroeste    21595,38229              4
# 2771     54  masculino    31,6  sudoeste       9850,432              3
#
#       atividade_fisica      dieta_saudavel  uso_medicamentos
# ...

# %%
base = base.fillna({'filhos' : 0,
                    'fumante' : 'não',
                    'doencas_cronicas' : 0})

# %%
## base['fumante'] = base['fumante'].fillna('Não')

# %%
## base['doencas_cronicas'] = base['doencas_cronicas'].fillna(0)

# %%
media_filhos = base['filhos'].mean()

# %%
media_filhos
# Out:
# 1.1017316017316017

# %%
base['fumante'].value_counts(dropna=False,normalize=True)
# Out:
# fumante
# não    0.796537
# sim    0.203463
# Name: proportion, dtype: float64

# %%
import sklearn

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
le_fumante = LabelEncoder()

# %%
oe_fumante = OrdinalEncoder()

# %%
le_regiao = LabelEncoder()

# %%
oe_regiao = OrdinalEncoder(categories=['nordeste',
                                       'noroeste',
                                       'noroeste',
                                       'sudoeste',
                                       'nordeste'])

# %%
base['fumante_cod'] = le_fumante.fit_transform(
                                        base['fumante'])

# %%
base['regiao_cod'] = le_regiao.fit_transform(
                                        base['regiao'])

# %%
dicionario_regiao = dict(enumerate(le_regiao.classes_))

# %%
dicionario_regiao
# Out:
# {0: 'nordeste', 1: 'noroeste', 2: 'sudeste', 3: 'sudoeste'}

# %%
base2 = pd.get_dummies(base, columns=['sexo'],dtype=int, drop_first=True)

# %%
base2
# Out:
#       idade     IMC  filhos fumante    regiao custos_medicos  \
# 0        19    27,9     0.0     sim  sudoeste      16884,924
# 1        18   33,77     1.0     não   sudeste      1725,5523
# 2        28      33     3.0     não   sudeste       4449,462
# 3        33  22,705     0.0     não  noroeste    21984,47061
# 4        32   28,88     0.0     não  noroeste      3866,8552
# ...     ...     ...     ...     ...       ...            ...
# 2767     47   45,32     1.0     não   sudeste      8569,8618
# 2768     21    34,6     0.0     não  sudoeste       2020,177
# 2769     19   26,03     1.0     sim  noroeste     16450,8947
# 2770     23  18,715     0.0     não  noroeste    21595,38229
# 2771     54    31,6     0.0     não  sudoeste       9850,432
#
#       doencas_cronicas  consultas_ano  atividade_fisica      dieta_saudavel  \
# 0                  0.0              4                 6  0,3901543721009203
# 1                  2.0              7                 3        0,3329179435
# ...
